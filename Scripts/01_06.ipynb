# %% [markdown]
# nombre entiers

# %%
a=25
a
# Out:
# 25

# %%
b=-788966666666666
b
# Out:
# -788966666666666

# %% [markdown]
# ## nombres flottants

# %%
a=2.23
a
# Out:
# 2.23

# %%
b=2.25e14
b
# Out:
# 225000000000000.0

# %% [markdown]
# ### nombres complexes

# %%
a= 2+3j
a
# Out:
# (2+3j)

# %%
type(a)
# Out:
# complex
